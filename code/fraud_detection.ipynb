# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r'E:\DEPI\Tech-Project\Fraud  detection\credit_card_transactions-ibm_v2.csv')

# %%
data.head(10)
# Out:
#    User  Card  Year  Month  Day   Time   Amount           Use Chip  \
# 0     0     0  2002      9    1  06:21  $134.09  Swipe Transaction
# 1     0     0  2002      9    1  06:42   $38.48  Swipe Transaction
# 2     0     0  2002      9    2  06:22  $120.34  Swipe Transaction
# 3     0     0  2002      9    2  17:45  $128.95  Swipe Transaction
# 4     0     0  2002      9    3  06:23  $104.71  Swipe Transaction
# 5     0     0  2002      9    3  13:53   $86.19  Swipe Transaction
# 6     0     0  2002      9    4  05:51   $93.84  Swipe Transaction
# 7     0     0  2002      9    4  06:09  $123.50  Swipe Transaction
# 8     0     0  2002      9    5  06:14   $61.72  Swipe Transaction
# 9     0     0  2002      9    5  09:35   $57.10  Swipe Transaction
#
#          Merchant Name  Merchant City Merchant State      Zip   MCC Errors?  \
# 0  3527213246127876953       La Verne             CA  91750.0  5300     NaN
# ...

# %%
data.shape
# Out:
# (24386900, 15)

# %%
data.columns
# Out:
# Index(['User', 'Card', 'Year', 'Month', 'Day', 'Time', 'Amount', 'Use Chip',
#        'Merchant Name', 'Merchant City', 'Merchant State', 'Zip', 'MCC',
#        'Errors?', 'Is Fraud?'],
#       dtype='object')

# %%
data.describe()
# Out:
#                User          Card          Year         Month           Day  \
# count  2.438690e+07  2.438690e+07  2.438690e+07  2.438690e+07  2.438690e+07
# mean   1.001019e+03  1.351366e+00  2.011955e+03  6.525064e+00  1.571812e+01
# std    5.694612e+02  1.407154e+00  5.105921e+00  3.472355e+00  8.794073e+00
# min    0.000000e+00  0.000000e+00  1.991000e+03  1.000000e+00  1.000000e+00
# 25%    5.100000e+02  0.000000e+00  2.008000e+03  3.000000e+00  8.000000e+00
# 50%    1.006000e+03  1.000000e+00  2.013000e+03  7.000000e+00  1.600000e+01
# 75%    1.477000e+03  2.000000e+00  2.016000e+03  1.000000e+01  2.300000e+01
# max    1.999000e+03  8.000000e+00  2.020000e+03  1.200000e+01  3.100000e+01
#
#        Merchant Name           Zip           MCC
# count   2.438690e+07  2.150876e+07  2.438690e+07
# mean   -4.769230e+17  5.095644e+04  5.561171e+03
# std     4.758940e+18  2.939707e+04  8.793154e+02
# min    -9.222899e+18  5.010000e+02  1.711000e+03
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24386900 entries, 0 to 24386899
# Data columns (total 15 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   User            int64
#  1   Card            int64
#  2   Year            int64
#  3   Month           int64
#  4   Day             int64
#  5   Time            object
#  6   Amount          object
#  7   Use Chip        object
#  8   Merchant Name   int64
#  9   Merchant City   object
#  10  Merchant State  object
#  11  Zip             float64
#  12  MCC             int64
#  13  Errors?         object
#  14  Is Fraud?       object
# dtypes: float64(1), int64(7), object(7)
# memory usage: 2.7+ GB

# %%
data.duplicated().sum()
# Out:
# 66

# %%
# drop dupicates values
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# User                     0
# Card                     0
# Year                     0
# Month                    0
# Day                      0
# Time                     0
# Amount                   0
# Use Chip                 0
# Merchant Name            0
# Merchant City            0
# Merchant State     2720821
# Zip                2878135
# MCC                      0
# Errors?           23998449
# Is Fraud?                0
# dtype: int64

# %%
# drop all nulls values
data.dropna(inplace=True)

# %%
# # Handel null values
# data['Merchant State']=data['Merchant State'].fillna('unknown')
# data['Zip']=data['Merchant State'].fillna('0')
# data['Errors?']=data['Errors?'].fillna('unknown')

# %%
data.isnull().sum()
# Out:
# User              0
# Card              0
# Year              0
# Month             0
# Day               0
# Time              0
# Amount            0
# Use Chip          0
# Merchant Name     0
# Merchant City     0
# Merchant State    0
# Zip               0
# MCC               0
# Errors?           0
# Is Fraud?         0
# dtype: int64

# %%
data.head()
# Out:
#     User  Card  Year  Month  Day   Time   Amount           Use Chip  \
# 21     0     0  2002      9    9  09:40   $65.50  Swipe Transaction
# 35     0     0  2002      9   12  06:21  $122.10  Swipe Transaction
# 49     0     0  2002      9   17  06:09  $120.19  Swipe Transaction
# 55     0     0  2002      9   20  06:01  $104.77  Swipe Transaction
# 81     0     0  2002      9   29  06:06  $119.61  Swipe Transaction
#
#           Merchant Name Merchant City Merchant State      Zip   MCC  \
# 21 -3345936507911876459      La Verne             CA  91750.0  7538
# 35  4060646732831064559      La Verne             CA  91750.0  5411
# 49   -34551508091458520      La Verne             CA  91750.0  5912
# 55  -245178307025547046      La Verne             CA  91750.0  5311
# 81  5817218446178736267      La Verne             CA  91750.0  5912
#
#                  Errors? Is Fraud?
# 21      Technical Glitch        No
# 35  Insufficient Balance        No
# 49  Insufficient Balance        No
# ...

# %%
data.shape
# Out:
# (324844, 15)

# %%
# save a dataframe in a csv file
data.to_csv('new_data.csv', index=False)
